# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt(r'C:\Users\au581149\PhD-Work\Lab Stuff\ESI\Ion signal from pulsed CIT\data_04_11_2024.txt', skiprows= 1)
taus = data[:,0]
Ns = data[:,1]
NPulses = data[:,2]

# %%
plt.bar(taus,Ns/NPulses,width = 10, align= 'edge')
plt.errorbar(taus+5,Ns/NPulses,np.sqrt(Ns)/NPulses, ls = '', color = 'k')
plt.xlabel('Detector delay w.r. to opening of CIT / µs')
plt.ylabel('Average number of ions per shot (N=10)')
NTot = np.sum(Ns/NPulses)
print(NTot)
plt.title(f'Average number of total detections: {NTot}')
# Out:
# 6.0
# Text(0.5, 1.0, 'Average number of total detections:')
